# %%
print(__doc__)

# Author: Alexandre Gramfort <alexandre.gramfort@inria.fr>
#         Fabian Pedregosa <fabian.pedregosa@inria.fr>
#
# License: BSD 3 clause (C) INRIA
###############################################################################

import numpy as np
import matplotlib.pyplot as plt
from sklearn import neighbors
# %matplotlib inline
# Out:
# Automatically created module for IPython interactive environment

# %%
# Generate sample data
np.random.seed(0)

# rand: [0,1] uniform distribution and order along rows
X = np.sort(5 * np.random.rand(40, 1), axis=0) 

T = np.linspace(0, 5, 500)[:, np.newaxis]  # divide (0,5) into 500 parts
y = np.cos(X).ravel() #flatten array

# Add noise to targets
y[::5] += 1 * ( 0.5 - np.random.rand(np.ceil(len(y)/5.)) )

###############################################################################
# Fit regression model
n_neighbors = 5

plt.figure(figsize=[15,5])
for i, weights in enumerate(['uniform', 'distance']):
    knn = neighbors.KNeighborsRegressor(n_neighbors, weights=weights)
#    y_ = knn.fit(X, y).predict(T)
    knn.fit(X,y) # training
    y_ = knn.predict(T) # prediction

    plt.subplot(1, 2, i + 1) # i start from 0
    plt.scatter(X, y, c='k', label='data')
    plt.plot(T, y_, c='g', label='prediction')
    plt.axis('tight')
    plt.legend()
    plt.title("KNeighborsRegressor (k = %i, weights = '%s')" % (n_neighbors, \
                                                                weights))

plt.show()
